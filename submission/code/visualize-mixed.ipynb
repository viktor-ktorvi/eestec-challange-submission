# %%
from visualization import visualize
from utils import load_as_dataframe
from load_model import boost_predict, svm_predict
import numpy as np
import os
import json
from matplotlib import pyplot as plt

# %%
figsize = (10, 6)

folder = 'data'
subfolder = 'mixed'
filename = 'mixed_farness_0_moving_0_radardata_2022_05_07_19_34_46.npz'

title = 'Mixed'
color = 'blue'

fig = visualize(os.path.join(folder, subfolder), filename, title, color, figsize=figsize)

df = load_as_dataframe(os.path.join(folder, subfolder), filename)

model_folder = 'svm_acc_95_2022_05_08_16_19_22'

with open(os.path.join(model_folder, 'hyperparams.json'), 'r') as f:
    hyperparams = json.load(f)

# pred = boost_predict(model_folder, df)
pred = svm_predict(model_folder, df)


pred_repeatd = np.repeat(pred, hyperparams['chunk_size'])
fig2 = plt.figure(figsize=figsize)
plt.plot(pred_repeatd)
fig2.tight_layout()
# Out:
# 100%|██████████| 20/20 [00:00<00:00, 110.60it/s]
